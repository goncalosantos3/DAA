# %% [markdown]
# # Decision Trees

# %% [markdown]
# Leitura dos datasets tratados

# %%
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

allowed_nans = ['', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN',
                '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NA',
                'NULL', 'NaN', 'n/a', 'nan', 'null']

treino = pd.read_csv('datasets/treinoTratado.csv', na_values=allowed_nans, keep_default_na=False)
teste = pd.read_csv('datasets/testeTratado.csv', na_values=allowed_nans, keep_default_na=False)

# %% [markdown]
# ## Construção e modelação

# %%
label_encoder = preprocessing.LabelEncoder() 

treino['Season']= label_encoder.fit_transform(treino['Season'])
teste['Season']= label_encoder.fit_transform(teste['Season'])

treino['weather_description']= label_encoder.fit_transform(treino['weather_description'])
teste['weather_description']= label_encoder.fit_transform(teste['weather_description'])

# %%
X_treino = treino.drop('Injeçao na rede (kWh)', axis=1)
y_treino = treino['Injeçao na rede (kWh)']

X_teste = teste

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=183)

params =  {'min_samples_leaf': list(range(1,15)), 'max_depth': list(range(1,15)), 'splitter':['best', 'random'], 'criterion':['gini','entropy']}
grid = GridSearchCV(estimator=clf,
                    param_grid=params,
                    cv=5,
                    n_jobs=5,
                    verbose=2)
grid.fit(X_treino, y_treino)
grid.best_score_, grid.best_params_
# Out:
# Fitting 5 folds for each of 784 candidates, totalling 3920 fits
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=best; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=best; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=1, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=3, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=5, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=best; total time=   0.2s[CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=random; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=random; total time=   0.1s[CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=best; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=random; total time=   0.1s[CV] END criterion=gini, max_depth=2, min_samples_leaf=9, splitter=best; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=2, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=random; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=random; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=random; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=random; total time=   0.1s
#
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=11, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=12, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=13, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=14, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=1, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=2, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=3, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=4, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=5, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=best; total time=   0.1s[CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=random; total time=   0.0s
#
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=6, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=7, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=8, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=9, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=10, splitter=best; total time=   0.1s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=10, splitter=best; total time=   0.2s
# [CV] END criterion=gini, max_depth=4, min_samples_leaf=10, splitter=random; total time=   0.1s
# ...
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=12, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=12, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=1, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=2, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=best; total time=   0.4s[CV] END criterion=entropy, max_depth=14, min_samples_leaf=3, splitter=best; total time=   0.4s
#
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=4, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=5, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=6, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=7, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=8, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=9, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=random; total time=   0.0s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=10, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=11, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=best; total time=   0.4s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=12, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=best; total time=   0.4s[CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=random; total time=   0.1s
#
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=13, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=random; total time=   0.1s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=best; total time=   0.3s
# [CV] END criterion=entropy, max_depth=14, min_samples_leaf=14, splitter=best; total time=   0.3s
# (0.7779166666666667,
#  {'criterion': 'gini',
#   'max_depth': 13,
#   'min_samples_leaf': 1,
#   'splitter': 'best'})

# %%
predictions = grid.predict(X_teste)

predict_data = {'Result': predictions}
df = pd.DataFrame(predict_data)
df.index += 1
df.index.name = 'RowId'

df.to_csv(f'predictions/dtPrediction.csv')
