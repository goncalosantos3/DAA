# %% [markdown]
# # Used Cars Dataset

# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\nunoc\miniconda3\envs\grinch\lib\site-packages (2.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\nunoc\miniconda3\envs\grinch\lib\site-packages (from xgboost) (1.26.0)
# Requirement already satisfied: scipy in c:\users\nunoc\miniconda3\envs\grinch\lib\site-packages (from xgboost) (1.11.1)

# %% [markdown]
# ## Phase 0: Imports and Reading Data

# %%
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn import preprocessing

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold, cross_validate
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
import numpy as np

# Set the number of columns to 14
pd.set_option('display.max_columns', 14)

# %%
cars = pd.read_csv('datasets/used_cars.csv')

# Set the target column to be the last one
cars = cars.reindex(columns = [col for col in cars.columns if col != 'Price'] + ['Price'])

# %% [markdown]
# ## Phase 1: Simple Data Exploration

# %%
cars.shape
# Out:
# (46022, 14)

# %%
cars.columns
# Out:
# Index(['Id', 'Company Name', 'Model Name', 'Model Year', 'Location', 'Mileage',
#        'Engine Type', 'Engine Capacity', 'Color', 'Assembly', 'Body Type',
#        'Transmission Type', 'Registration Status', 'Price'],
#       dtype='object')

# %%
cars.head()
# Out:
#    Id Company Name Model Name  Model Year   Location  Mileage Engine Type  \
# 0   0       Toyota       Vitz        2017  Islamabad     9869      Petrol
# 1   1       Toyota    Corolla        2019        KPK    11111      Petrol
# 2   2       Suzuki       Alto        2019        KPK    17500      Petrol
# 3   3       Suzuki       Alto        2019     Punjab     9600      Petrol
# 4   4       Toyota    Corolla        2010  Islamabad   120000      Petrol
#
#    Engine Capacity   Color  Assembly  Body Type Transmission Type  \
# 0             1000  Silver  Imported  Hatchback         Automatic
# 1             1300   White     Local      Sedan         Automatic
# 2              660   White     Local  Hatchback         Automatic
# 3              660   White     Local  Hatchback            Manual
# 4             1300   Black     Local      Sedan            Manual
#
#   Registration Status    Price
# 0       Un-Registered  2385000
# 1          Registered   111000
# 2       Un-Registered  1530000
# 3          Registered  1650000
# 4          Registered  1435000

# %%
cars.describe()
# Out:
#                  Id    Model Year        Mileage  Engine Capacity  \
# count  46022.000000  46022.000000   46022.000000     46022.000000
# mean   23010.526205   2011.035374   90965.128243      1313.115575
# std    13285.595581      6.399403   63656.656034       614.690832
# min        0.000000   1990.000000       1.000000        16.000000
# 25%    11505.250000   2007.000000   48899.500000      1000.000000
# 50%    23010.500000   2013.000000   80000.000000      1300.000000
# 75%    34515.750000   2016.000000  120000.000000      1500.000000
# max    46022.000000   2019.000000  999999.000000      6600.000000
#
#               Price
# count  4.602200e+04
# mean   2.014153e+06
# std    2.939071e+06
# min    1.110000e+05
# 25%    8.500000e+05
# 50%    1.450000e+06
# 75%    2.300000e+06
# max    7.750000e+07

# %%
cars.duplicated().any()
# Out:
# False

# %%
cars.isna().any()
# Out:
# Id                     False
# Company Name           False
# Model Name             False
# Model Year             False
# Location               False
# Mileage                False
# Engine Type            False
# Engine Capacity        False
# Color                  False
# Assembly               False
# Body Type              False
# Transmission Type      False
# Registration Status    False
# Price                  False
# dtype: bool

# %%
cars.dtypes
# Out:
# Id                      int64
# Company Name           object
# Model Name             object
# Model Year              int64
# Location               object
# Mileage                 int64
# Engine Type            object
# Engine Capacity         int64
# Color                  object
# Assembly               object
# Body Type              object
# Transmission Type      object
# Registration Status    object
# Price                   int64
# dtype: object

# %%
cars['Color'].value_counts()
# Out:
# Color
# White        17588
# Silver        8006
# Black         6026
# Grey          5038
# Blue          2127
# Assembly      1382
# Gold          1003
# Maroon         924
# Red            822
# Green          770
# Beige          580
# Burgundy       307
# Brown          269
# Turquoise      230
# Bronze         211
# Pink           194
# Navy           120
# Unlisted       109
# Yellow          98
# Purple          90
# Indigo          85
# Orange          40
# Magenta          2
# Wine             1
# Name: count, dtype: int64

# %%
cars['Body Type'].value_counts()
# Out:
# Body Type
# Hatchback     21576
# Sedan         18984
# SUV            2390
# Mini Van       1199
# Cross Over     1182
# Van             691
# Name: count, dtype: int64

# %%
cars['Engine Type'].value_counts()
# Out:
# Engine Type
# Petrol    43590
# Hybrid     1439
# Diesel      993
# Name: count, dtype: int64

# %%
cars['Assembly'].value_counts()
# Out:
# Assembly
# Local       31210
# Imported    14812
# Name: count, dtype: int64

# %%
cars['Transmission Type'].value_counts()
# Out:
# Transmission Type
# Manual       24611
# Automatic    21411
# Name: count, dtype: int64

# %%
cars['Registration Status'].value_counts()
# Out:
# Registration Status
# Registered       42693
# Un-Registered     3329
# Name: count, dtype: int64

# %% [markdown]
# ## Phase 2: Data Preparation

# %% [markdown]
# We know that the 'Id' column is useless and it doesn't have any relevance to the target column 'Price'. Because of this, we can simply remove this column.

# %%
cars.drop('Id', inplace=True, axis=1)

# %% [markdown]
# **Note**: The column 'Location' is probably useless as well and should be removed.

# %% [markdown]
# Another good thing that we could do is to convert the column 'Mileage' to its corresponding values in kilometers.

# %%
def convert(m):
    return int(m * 1.609344)

kms = cars['Mileage'].apply(convert)
cars['Mileage'] = kms
cars.rename(columns = {'Mileage':'Kilometers'}, inplace = True)

# %% [markdown]
# There are some missing values in the 'Color' column. Because this is a categorical column and only 3.75% of the dataset have missing values we decided to remove the rows with missing values.

# %%
cars.drop(cars[cars['Color'] == 'Assembly'].index, inplace = True)
cars.drop(cars[cars['Color'] == 'Unlisted'].index, inplace = True)

# %% [markdown]
# For the purpose of better Data Understanding, we are going to proceed to the binning of the colors.

# %%
color_map = {'Beige': 'Warm',
             'Black': 'Dark',
             'Blue': 'Cool',
             'Bronze': 'Warm',
             'Brown': 'Warm',
             'Burgundy': 'Warm',
             'Gold': 'Warm',
             'Green': 'Cool',
             'Grey': 'Dark',
             'Indingo': 'Cool',
             'Magenta': 'Warm',
             'Maroon': 'Warm',
             'Navy': 'Cool',
             'Orange': 'Warm',
             'Pink': 'Warm',
             'Purple': 'Cool',
             'Red': 'Warm',
             'Silver': 'Dark',
             'Turquoise': 'Cool',
             'White': 'Bright',
             'Wine': 'Warm',
             'Yellow': 'Warm'}

cars['Mapped_colors'] = cars['Color'].map(color_map)

# %% [markdown]
# The column 'Location' represents the location of the cars, basically where they are available for purchase. The values of this column belong to two countries: India and Pakistan.

# %%
location_map = {'Islamabad': 'Pakistan',
                'KPK': 'Pakistan',
                'Punjab': 'India',
                'Sindh': 'Pakistan',
                'Balochistan': 'Pakistan',
                'Kashmir': 'India'}

cars['Mapped_locations'] = cars['Location'].map(location_map)

# %% [markdown]
# ## Phase 3: Deep Data Exploration

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 10))
sns.countplot(data=cars, x='Assembly', ax=ax[0, 0])
sns.countplot(data=cars, x='Registration Status', ax=ax[0, 1])
body_tp = sns.countplot(data=cars, x='Body Type', ax=ax[0, 2])
body_tp.tick_params(axis='x', rotation=45)
sns.countplot(data=cars, x='Engine Type', ax=ax[1, 0])
location = sns.countplot(data=cars, x='Location', ax=ax[1, 1])
location.tick_params(axis='x', rotation=90)
sns.countplot(data=cars, x='Transmission Type', ax=ax[1, 2])

plt.show()

# %%
ax1 = sns.barplot(x=cars['Company Name'].unique(), y= cars['Company Name'].value_counts())
ax1.tick_params(axis='x', rotation=90)
plt.show()
ax2 = sns.barplot(x=cars['Model Year'].unique(), y= cars['Model Year'].value_counts())
ax2.tick_params(axis='x', rotation=90)

plt.show()

# %%
graf = cars['Price'].value_counts().head(30).plot(kind='bar', title="Top 30 most common prices")
graf.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
graf = cars['Price'].plot(kind='kde', title='Price distribuiton')
graf.set_xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %% [markdown]
# #### Relation: 'Company Name' with 'Price'

# %%
cars.groupby(by=['Company Name'])['Price'].mean()
# Out:
# Company Name
# Adam          2.100000e+05
# Audi          8.555778e+06
# BMW           5.675694e+06
# Chery         5.337500e+05
# Chevrolet     6.803947e+05
# DFSK          2.029444e+06
# Daewoo        3.169565e+05
# Daihatsu      1.165193e+06
# FAW           1.023500e+06
# Fiat          3.550000e+05
# Honda         2.142730e+06
# Hummer        1.500000e+07
# Hyundai       6.226275e+05
# Jaguar        1.400000e+07
# Jeep          4.516667e+06
# KIA           2.082308e+06
# Land          3.213889e+06
# Lexus         1.369262e+07
# MINI          3.570000e+06
# Mazda         1.351019e+06
# Mercedes      5.191007e+06
# Mitsubishi    1.258449e+06
# Nissan        1.609835e+06
# Porsche       1.875000e+07
# Range         1.395438e+07
# SsangYong     1.637917e+06
# Subaru        1.262288e+06
# Suzuki        9.031436e+05
# Toyota        2.985915e+06
# United        8.597031e+05
# Volvo         1.275000e+06
# Name: Price, dtype: float64

# %% [markdown]
# #### Relation: 'Company Name' and 'Model Name' with 'Price'

# %%
cars.groupby(by=['Company Name', 'Model Name'])['Price'].mean()
# Out:
# Company Name  Model Name
# Adam          Revo          2.100000e+05
# Audi          A3            5.861667e+06
#               A4            6.702318e+06
#               A5            1.118810e+07
#               A6            1.137738e+07
#                                 ...
# Toyota        Voxy          4.018182e+06
#               Wish          2.110769e+06
#               iQ            1.446667e+06
# United        Bravo         8.597031e+05
# Volvo         S40           1.275000e+06
# Name: Price, Length: 197, dtype: float64

# %% [markdown]
# #### Relation: 'Color' with 'Price'

# %%
cars.groupby(by=['Color'])['Price'].mean()
# Out:
# Color
# Beige        1.443181e+06
# Black        2.978100e+06
# Blue         1.356260e+06
# Bronze       2.168867e+06
# Brown        2.238717e+06
# Burgundy     2.181375e+06
# Gold         1.203126e+06
# Green        1.280708e+06
# Grey         1.449484e+06
# Indigo       1.715553e+06
# Magenta      1.400000e+06
# Maroon       1.439175e+06
# Navy         1.920408e+06
# Orange       2.006875e+06
# Pink         1.331665e+06
# Purple       2.003667e+06
# Red          1.569943e+06
# Silver       1.721924e+06
# Turquoise    1.346222e+06
# White        2.197988e+06
# Wine         1.190000e+06
# Yellow       1.334398e+06
# Name: Price, dtype: float64

# %%
sns.barplot(x='Mapped_colors', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Assembly' with 'Price'

# %%
sns.barplot(x='Assembly', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Registration Status' with 'Price'

# %%
sns.barplot(x='Registration Status', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Body Type' with 'Price'

# %%
sns.barplot(x='Body Type', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Location' with 'Price'

# %%
sns.barplot(x='Location', y='Price', data=cars)
plt.show()

# %%
sns.barplot(x='Mapped_locations', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Transmission Type' with 'Price'

# %%
sns.barplot(x='Transmission Type', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Engine Type' with 'Price'

# %%
sns.barplot(x='Engine Type', y='Price', data=cars)
plt.show()

# %% [markdown]
# #### Relation: 'Engine Capacity' with 'Price'

# %%
graf = sns.scatterplot(x='Engine Capacity', y='Price', data=cars)
graf.set_title('Engine Capacity vs Price')
plt.show()

# %% [markdown]
# #### Relation: 'Engine Capacity' and 'Engine Type' with 'Price'

# %%
graf = sns.scatterplot(x='Engine Capacity', y='Price', hue='Engine Type', data=cars)
graf.set_title('Engine Capacity vs Price')
plt.show()

# %% [markdown]
# #### Relation: 'Kilometers' with 'Price'

# %%
graf = sns.scatterplot(x='Kilometers', y='Price', data=cars)
graf.set_title('Kilometers vs Price')
plt.show()

# %% [markdown]
# #### Relation: 'Model Year' with 'Price'

# %%
graf = sns.scatterplot(x='Model Year', y='Price', data=cars)
graf.set_title('Model Year vs Price')
plt.show()

# %% [markdown]
# ## Phase 4: Preparation Pre Modelling

# %% [markdown]
# #### Correlation Matrix

# %%
from sklearn.preprocessing import LabelEncoder

columns_to_encode = ['Company Name', 'Model Name', 'Location',
                     'Engine Type', 'Color', 'Assembly', 'Body Type', 'Transmission Type', 
                     'Registration Status', 'Mapped_colors', 'Mapped_locations']

label_encoder = LabelEncoder()
for column in columns_to_encode:
    cars[column] = label_encoder.fit_transform(cars[column])

# %%
corr_matrix = cars.corr(numeric_only=True)
sns.heatmap(corr_matrix, vmin=-1, vmax=1, square=True, annot=True)
plt.show()

# %%
cars[cars.columns[1:]].corr()['Price'][:]
# Out:
# Model Name             0.050729
# Model Year             0.217971
# Location              -0.036827
# Kilometers            -0.188354
# Engine Type           -0.069132
# Engine Capacity        0.646900
# Color                 -0.020958
# Assembly              -0.264244
# Body Type              0.155299
# Transmission Type     -0.340638
# Registration Status    0.204849
# Price                  1.000000
# Mapped_colors         -0.048264
# Mapped_locations       0.040825
# Name: Price, dtype: float64

# %%
columns_to_drop = ['Color', 'Location', 'Mapped_locations']

cars.drop(columns=columns_to_drop, inplace=True, axis=1)

# %%
X = cars.drop('Price', axis=1)
y = cars['Price']

# %%
from xgboost import XGBRegressor
import xgboost as xgb
import lightgbm as lgb
from sklearn.neural_network import MLPRegressor
from catboost import CatBoostRegressor
from sklearn.svm import SVR
# Create a list of regression model
models = [
    ("Linear Regression", LinearRegression()),
    ("Decision Tree Regression", DecisionTreeRegressor(random_state=2023)),
    ("Random Forest Regression", RandomForestRegressor(random_state=2023)),
    ("ExtraTrees",ExtraTreesRegressor(random_state=2023)),
    ("GradientBoosting",GradientBoostingRegressor(random_state=2023)),
    ("XGBoost", xgb.XGBRegressor(random_state=2023)),
    ("LightGBM",lgb.LGBMRegressor(random_state=2023,verbose=-1)),
    #("MLP",MLPRegressor(random_state=183, max_iter=2000))
    ("CatBoost",CatBoostRegressor(random_seed=2023)),
    ("SVR",SVR())
]

# Iterate through the models, train, and evaluate them
for model_name, model in models:
    scoring = {
        'mse': 'neg_mean_squared_error',
        'mae': 'neg_mean_absolute_error',
        'r2': 'r2',
        'rmse': make_scorer(lambda y_true, y_pred: np.sqrt(mean_squared_error(y_true, y_pred)))
    }


    kf = KFold(n_splits=5, shuffle= True, random_state=2023)
    results = cross_validate(model, X, y, cv=kf, scoring=scoring)


    # Print the results
    print(f"Model: {model_name}")
    print(f"Average Cross-validated MSE: {np.mean(-results['test_mse']):.2f}")
    print(f"Average Cross-validated MAE: {np.mean(-results['test_mae']):.2f}")
    print(f"Average Cross-validated R2: {np.mean(results['test_r2']):.4f}")
    print(f"Average Cross-validated RMSE: {np.mean(results['test_rmse']):.2f}")
    print("-" * 40)
# Out:
# Model: Linear Regression
# Average Cross-validated MSE: 3474524859815.89
# Average Cross-validated MAE: 853524.68
# Average Cross-validated R2: 0.5872
# Average Cross-validated RMSE: 1863278.32
# ----------------------------------------
# Model: Decision Tree Regression
# Average Cross-validated MSE: 643671463730.34
# Average Cross-validated MAE: 214282.74
# Average Cross-validated R2: 0.9235
# Average Cross-validated RMSE: 795937.50
# ----------------------------------------
# Model: Random Forest Regression
# Average Cross-validated MSE: 398373454581.18
# Average Cross-validated MAE: 178256.48
# Average Cross-validated R2: 0.9526
# Average Cross-validated RMSE: 623467.99
# ----------------------------------------
# Model: ExtraTrees
# Average Cross-validated MSE: 385339071273.02
# Average Cross-validated MAE: 185253.96
# Average Cross-validated R2: 0.9541
# Average Cross-validated RMSE: 615424.91
# ----------------------------------------
# Model: GradientBoosting
# Average Cross-validated MSE: 528258720785.15
# Average Cross-validated MAE: 256537.47
# Average Cross-validated R2: 0.9371
# Average Cross-validated RMSE: 723234.04
# ----------------------------------------
# Model: XGBoost
# Average Cross-validated MSE: 393329869364.02
# Average Cross-validated MAE: 179118.35
# Average Cross-validated R2: 0.9533
# Average Cross-validated RMSE: 621673.20
# ----------------------------------------
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001540 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 540
# [LightGBM] [Info] Number of data points in the train set: 35624, number of used features: 11
# [LightGBM] [Info] Start training from score 2004583.904110
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 543
# [LightGBM] [Info] Number of data points in the train set: 35625, number of used features: 11
# [LightGBM] [Info] Start training from score 2007601.628070
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001486 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 539
# [LightGBM] [Info] Number of data points in the train set: 35625, number of used features: 11
# [LightGBM] [Info] Start training from score 2002258.807018
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001570 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 541
# [LightGBM] [Info] Number of data points in the train set: 35625, number of used features: 11
# [LightGBM] [Info] Start training from score 1995762.357895
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001415 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 538
# [LightGBM] [Info] Number of data points in the train set: 35625, number of used features: 11
# [LightGBM] [Info] Start training from score 2016132.575439
# Model: LightGBM
# Average Cross-validated MSE: 447983127367.79
# Average Cross-validated MAE: 195587.32
# Average Cross-validated R2: 0.9466
# Average Cross-validated RMSE: 662218.36
# ----------------------------------------
# c:\Users\nunoc\miniconda3\envs\grinch\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:693: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
cars.to_csv(f'datasets/used_carsTratado.csv', index=False)
